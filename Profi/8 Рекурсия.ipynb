# %% [markdown]
# <a href="https://colab.research.google.com/github/aleks-haksly/GenerationPython/blob/main/Profi/8%20%D0%A0%D0%B5%D0%BA%D1%83%D1%80%D1%81%D0%B8%D1%8F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://stepik.org/lesson/637962/step/5?unit=634429

# %%
def traffic(n):
    if n > 0:
        print('Не парковаться')
        traffic(n - 1)

# %% [markdown]
# https://stepik.org/lesson/637962/step/6?unit=634429

# %%
def func(start, end):
    if start <= end:
        print(start)
        func(start + 1, end)

func(1, 100)

# %% [markdown]
# https://stepik.org/lesson/637962/step/7?unit=634429

# %%
numbers = [243, -279, 395, 130, 89, 269, 861, 669, 939, 367, -46, 710, 841, -280, -244, 274, -132, 273, 418, 432, -341, 437, 360, 960, 195, 792, 106, 461, -35, 980, -80, 540, -358, 69, -26, -416, 597, 96, 533, 232, 755, 894, 331, 323, -383, -386, 231, 436, 553, 967, 166, -151, 772, 434, 325, 301, 275, 431, 556, 728, 558, 702, 463, 127, 984, 212, 876, -287, -16, -177, 577, 604, 116, 500, 653, 669, 916, 802, 817, 762, -210, -353, 144, -351, 777, 805, 692, 22, -303, 249, 190, 411, 236, -274, 174, 380, 71, 124, -85, 430]

# %% [markdown]
# ```
# Элемент 0: 243
# Элемент 1: -279
# Элемент 2: 395
# ...
# ```

# %%
def print_nums(n, start=0):
  if n:
    print(f'Элемент {start}: {n.pop(0)}')
    print_nums(n, start+1)
print_nums(numbers)

# %% [markdown]
# https://stepik.org/lesson/637962/step/8?unit=634429

# %%
def func(num):
    if not num == '0':
        func(input())
    print(num)

func(input())

# %% [markdown]
# https://stepik.org/lesson/637962/step/9?unit=634429

# %%
def triangle(num):
    if num > 0:
        print('*' * num)
        triangle(num-1)

# %% [markdown]
# https://stepik.org/lesson/637962/step/10?unit=634429

# %%
def triangle(num):
    if num > 0:
        triangle(num-1)
        print('*' * num)

# %% [markdown]
# https://stepik.org/lesson/637962/step/11?unit=634429

# %%
def watch(x=16, y=1):
    if x != y:
        print((f'{y}' * x).center(16))
        watch(x - 4, y + 1)
    print((f'{y}' * x).center(16))

watch()
# Out:
# 1111111111111111
#   222222222222
#     33333333
#       4444
#     33333333
#   222222222222
# 1111111111111111

# %% [markdown]
# https://stepik.org/lesson/637962/step/12?unit=634429

# %%
def print_digits(number):
    if number > 0:
        print(number % 10)
        print_digits(number // 10)

# %% [markdown]
# https://stepik.org/lesson/637962/step/13?unit=634429

# %%
def print_digits(number):
    if number > 0:
        print_digits(number // 10)
        print(number % 10)

# %% [markdown]
# https://stepik.org/lesson/594137/step/6?unit=589173

# %%
def ln(n:int):
    if n < 10 :
        return 1
    return 1 + ln(n // 10)

# %% [markdown]
# https://stepik.org/lesson/594137/step/7?unit=589173

# %%
def sum_digits(number):
    if number < 10:
        return number
    return number % 10 + sum_digits(number // 10)

num = 25
print(sum_digits(int(input())))
# Out:
# 12
# 3

# %% [markdown]
# https://stepik.org/lesson/594137/step/8?unit=589173

# %%
def number_of_frogs(year):
    if year == 1:
        return 77
    return 3 * (number_of_frogs(year - 1) - 30)

# %% [markdown]
# https://stepik.org/lesson/594137/step/9?unit=589173

# %%
def range_sum(numbers, start, end):
    if start > end:
        return 0
    return numbers[start] + range_sum(numbers, start+1, end)

# %% [markdown]
# https://stepik.org/lesson/594137/step/10?unit=589173

# %%
def get_pow(a, n):
    if n == 0:
        return 1
    return a * get_pow(a, n-1)

# %% [markdown]
# https://stepik.org/lesson/594137/step/11?unit=589173

# %%
def get_fast_pow(a, n):
    if n == 0:
        return 1
    elif n % 2 == 0:
        return get_fast_pow(a * a, n // 2)
    return a * get_fast_pow(a, n-1)

# %% [markdown]
# https://stepik.org/lesson/594137/step/12?unit=589173

# %%
def recursive_sum(a, b):
    if b == 0:
        return a
    return recursive_sum(a + 1, b - 1)

# %% [markdown]
# https://stepik.org/lesson/594137/step/13?unit=589173

# %%
def is_power(number):
    if number == 1:
        return True
    elif number % 2 == 0:
        return is_power(number / 2)
    else:
        return False

# %% [markdown]
# https://stepik.org/lesson/594137/step/14?unit=589173

# %%
def tribonacci(n, memo={1: 1, 2: 1, 3: 1}):
    if n in memo:
        return memo[n]
    memo[n] = tribonacci(n - 1, memo) + tribonacci(n - 2, memo) + tribonacci(n - 3, memo)
    return memo[n]

# %% [markdown]
# https://stepik.org/lesson/594137/step/15?unit=589173

# %%
def is_palindrome(string):
    if len(string) <= 1:
        return True
    if string[0] != string[-1]:
        return False
    return is_palindrome(string[1:-1])

# %% [markdown]
# https://stepik.org/lesson/594137/step/16?unit=589173

# %%
def to_binary(number):
    if number == 0:
        return '0'
    if number == 1:
        return '1'
    return to_binary(number // 2) + str(number % 2)

# %% [markdown]
# https://stepik.org/lesson/594137/step/17?unit=589173

# %%
def plus_minus_five(number):
    print(number)
    if number > 0:
        plus_minus_five(number - 5)
        print(number)
